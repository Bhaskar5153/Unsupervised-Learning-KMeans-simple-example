# %%
import numpy as np
import pandas as pd

# %%
my_data = np.random.randint(0, 10000, (1000, 4))

# %%
my_data.shape
# Out:
# (1000, 4)

# %%
my_data
# Out:
# array([[9451, 6592, 7768, 1538],
#        [1015, 3586,    1, 9832],
#        [5540,  530, 9728,  151],
#        ...,
#        [9857, 8920, 8744, 8689],
#        [7928, 4118, 5161, 1983],
#        [4485, 4139,  698, 7310]])

# %%
df = pd.DataFrame(data=my_data, columns=['p1', 'p2', 'p3', 'p4'])

# %%
df
# Out:
#        p1    p2    p3    p4
# 0    9451  6592  7768  1538
# 1    1015  3586     1  9832
# 2    5540   530  9728   151
# 3    2170  8150  5630  6523
# 4    6037  3643   228  2344
# ..    ...   ...   ...   ...
# 995  5466  7585  4962  5148
# 996  2119  5322  8808  7687
# 997  9857  8920  8744  8689
# 998  7928  4118  5161  1983
# 999  4485  4139   698  7310
#
# [1000 rows x 4 columns]

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from autoviz import AutoViz_Class

AV = AutoViz_Class()


dft = AV.AutoViz(filename='', dfte=df)
# Out:
# Shape of your Data Set loaded: (1000, 4)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_d1e56_row0_col0, #T_d1e56_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_d1e56_row0_col1, #T_d1e56_row0_col6, #T_d1e56_row1_col1, #T_d1e56_row1_col6, #T_d1e56_row2_col1, #T_d1e56_row2_col6, #T_d1e56_row3_col1, #T_d1e56_row3_col6 {
#   font-family: Segoe UI;
# }
# ...

# %%
plt.figure(figsize=(12, 6), dpi=60)

sns.histplot(data=df, x='p1', kde=True)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=4)

# %%
cluster_labels = model.fit_predict(df)

# %%
cluster_labels[0:10]
# Out:
# array([1, 0, 3, 0, 2, 2, 0, 2, 3, 1])

# %%
sum_of_squared_distance = []

# %%
for k in range(2, 10):
    
    model = KMeans(n_clusters=k)
    model.fit(df)
    
    
    sum_of_squared_distance.append(model.inertia_)

# %%
sum_of_squared_distance
# Out:
# [26341891266.55635,
#  22485002306.07676,
#  19507064374.49249,
#  17327054555.356606,
#  15672680194.976683,
#  14173377850.93587,
#  12770919596.15087,
#  11915629380.068026]

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(2, 10), sum_of_squared_distance, 'o--', markersize=15)
